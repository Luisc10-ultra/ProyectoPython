# %% [markdown]
# # Proyecto 02
# * Buscar datos del precia de las acciones
# * hacer analisis solicitados por el gestor
# * cotizacion maxima
# * cotizacion minima
# * valor medio
#  * enviar correo

# %% [markdown]
# ## Buscar datos del precio de las acciones

# %%
# %pip install yfinance
# %pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    --------------------- ------------------ 1.0/2.0 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 6.9 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    ------------------------------ --------- 3.1/4.1 MB 25.6 MB/s eta 0:00:01
#    ------------------------------ --------- 3.1/4.1 MB 25.6 MB/s eta 0:00:01
#    ------------------------------ --------- 3.1/4.1 MB 25.6 MB/s eta 0:00:01
#    ------------------------------ --------- 3.1/4.1 MB 25.6 MB/s eta 0:00:01
#    ------------------------------ --------- 3.1/4.1 MB 25.6 MB/s eta 0:00:01
#    ------------------------------ --------- 3.1/4.1 MB 25.6 MB/s eta 0:00:01
#    ------------------------------ --------- 3.1/4.1 MB 25.6 MB/s eta 0:00:01
#    --------------------------------- ------ 3.4/4.1 MB 2.1 MB/s eta 0:00:01
# ...

# %%
import yfinance

# %%
tiker = input("Escriba el código de la acción: ")

data = yfinance.download([tiker], period="6mo")

cierre = data.Close[tiker]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.High
# Out:
# Ticker            AAPL
# Date
# 2026-03-16  253.437730
# 2026-03-17  254.675521
# 2026-03-18  254.485859
# 2026-03-19  251.381408
# 2026-03-20  248.756069
# ...                ...
# 2026-09-09  319.149994
# 2026-09-10  326.739990
# 2026-09-11  336.220001
# 2026-09-14  335.500000
# 2026-09-15  331.779999
#
# [127 rows x 1 columns]

# %%
data["High"]

cierre = data.Close["AAPL"]

# %%
data.Close["AAPL"]
# Out:
# Date
# 2026-03-16    252.369644
# 2026-03-17    253.777115
# 2026-03-18    249.494766
# 2026-03-19    248.516525
# 2026-03-20    247.548233
#                  ...
# 2026-09-09    315.339996
# 2026-09-10    326.570007
# 2026-09-11    332.269989
# 2026-09-14    333.079987
# 2026-09-15    331.339996
# Name: AAPL, Length: 127, dtype: float64

# %%
cierre
# Out:
# Date
# 2026-03-16    252.369644
# 2026-03-17    253.777115
# 2026-03-18    249.494766
# 2026-03-19    248.516525
# 2026-03-20    247.548233
#                  ...
# 2026-09-09    315.339996
# 2026-09-10    326.570007
# 2026-09-11    332.269989
# 2026-09-14    333.079987
# 2026-09-15    331.339996
# Name: AAPL, Length: 127, dtype: float64

# %%
cierre.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## hacer los analisis solicitados por el gestor

# %%
cierre
# Out:
# Date
# 2026-03-16    252.369644
# 2026-03-17    253.777115
# 2026-03-18    249.494766
# 2026-03-19    248.516525
# 2026-03-20    247.548233
#                  ...
# 2026-09-09    315.339996
# 2026-09-10    326.570007
# 2026-09-11    332.269989
# 2026-09-14    333.079987
# 2026-09-15    331.339996
# Name: AAPL, Length: 127, dtype: float64

# %%
maxima = round(cierre.max(), 2)
minima = round(cierre.min(), 2)
valor_medio = round(cierre.mean(), 2)

# %%
print(maxima, minima, valor_medio)
# Out:
# 339.79 246.19 295.82

# %%
print(maxima)
# Out:
# 339.79

# %% [markdown]
# ## Enviar los emails

# %%
# %pip install pyautogui
# %pip install pyperclip
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
# ...

# %%
import pyautogui
import pyperclip
import webbrowser
import time

# %%
webbrowser.open("https://mail.google.com/mail/u/0/#inbox")

destinatario = "luiscbarcelonista10@gmail.com"
asunto = "Análisis acciones últimos 6 meses"
mensaje = f"""
Buenas noches pendejo

Acá te envío el análisis de las acciones de apple que odiamos de los últimos 6 meses de gays: 

Cotización máxima: USD {maxima}
Cotización mínima: USD {minima}
Valor medio: USD {valor_medio}

Estoy hasta la madre 

saludos,
Tu rodilla izquierda
"""

time.sleep(3)

pyautogui.PAUSE = 3

pyautogui.click(95, 286)
pyautogui.click(1313, 440)

pyperclip.copy(destinatario)
pyautogui.hotkey("ctrl", "v")

pyautogui.hotkey("tab")

pyperclip.copy(asunto)
pyautogui.hotkey("ctrl", "v")

pyautogui.hotkey("tab")

pyperclip.copy(mensaje)
pyautogui.hotkey("ctrl", "v")

pyautogui.click(1245, 969)

pyautogui.hotkey("ctrl", "w")

# %%
time.sleep(3)

pyautogui.position()
# Out:
# Point(x=1245, y=969)
